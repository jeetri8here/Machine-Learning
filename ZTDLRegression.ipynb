# %% [markdown]
# # Data Description

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_excel("Real estate valuation data set.xlsx")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   No                                      414 non-null    int64
#  1   X1 transaction date                     414 non-null    float64
#  2   X2 house age                            414 non-null    float64
#  3   X3 distance to the nearest MRT station  414 non-null    float64
#  4   X4 number of convenience stores         414 non-null    int64
#  5   X5 latitude                             414 non-null    float64
#  6   X6 longitude                            414 non-null    float64
#  7   Y house price of unit area              414 non-null    float64
# dtypes: float64(6), int64(2)
# memory usage: 26.0 KB

# %%
sns.pairplot(data, hue='Y house price of unit area')

# %%
corr = data.corr()
data.corr()
# Out:
#                                               No  ...  Y house price of unit area
# No                                      1.000000  ...                   -0.028587
# X1 transaction date                    -0.048634  ...                    0.087529
# X2 house age                           -0.032808  ...                   -0.210567
# X3 distance to the nearest MRT station -0.013573  ...                   -0.673613
# X4 number of convenience stores        -0.012699  ...                    0.571005
# X5 latitude                            -0.010110  ...                    0.546307
# X6 longitude                           -0.011059  ...                    0.523287
# Y house price of unit area             -0.028587  ...                    1.000000
#
# [8 rows x 8 columns]

# %%
sns.heatmap(
    corr, 
    square=True)

# %%
features = data.iloc[:,1:7].values #Dropping userID because it may affect the Algorithm
label = data.iloc[:,[7]].values

# %% [markdown]
# # # Model Buidling with Linear Models

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
for i in range(0,401):
    
    X_train,X_test,y_train,y_test = train_test_split(features,
                                                label,
                                                test_size=0.2,
                                                random_state=i)
    model = LinearRegression()
    model.fit(X_train,y_train)
    
    train_score = model.score(X_train,y_train)
    test_score = model.score(X_test,y_test)
    
    if test_score > train_score:
        print("Testing {}  Training {}  Random State {}".format(test_score,train_score,i))
else: print("No Generalised Model Found")
# Out:
# Testing 0.657356729182853  Training 0.5648155773967247  Random State 0
# Testing 0.7034451627533804  Training 0.5506155158883823  Random State 1
# Testing 0.6056371825192507  Training 0.5747136823383557  Random State 3
# Testing 0.5845847268703224  Training 0.5793561665070799  Random State 5
# Testing 0.7015037821111005  Training 0.5524735983830324  Random State 8
# Testing 0.5941551132009615  Training 0.575469719527272  Random State 10
# Testing 0.6140784481886834  Training 0.5740180649527586  Random State 12
# Testing 0.5984844145574817  Training 0.5781339741211673  Random State 13
# Testing 0.657722716701513  Training 0.5623090755117204  Random State 14
# Testing 0.6027067725142112  Training 0.5749870891570034  Random State 15
# Testing 0.6372105081129897  Training 0.5657783410450274  Random State 17
# Testing 0.629613870022883  Training 0.5733826570523823  Random State 19
# Testing 0.6481421203732856  Training 0.5685422516345585  Random State 20
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso
for i in range(0,401):
    
    X_train,X_test,y_train,y_test = train_test_split(features,
                                                label,
                                                test_size=0.2,
                                                random_state=i)
    model = Lasso()
    model.fit(X_train,y_train)
    
    train_score = model.score(X_train,y_train)
    test_score = model.score(X_test,y_test)
    
    if test_score > train_score:
        print("Testing {}  Training {}  Random State {}".format(test_score,train_score,i))
else: print("No Generalised Model Found")
# Out:
# Testing 0.6181623505364959  Training 0.5208930533308123  Random State 0
# Testing 0.6777282193290388  Training 0.5036585417844894  Random State 1
# Testing 0.5496135655469524  Training 0.5367602925415385  Random State 3
# Testing 0.5545843872063605  Training 0.5358259031137673  Random State 5
# Testing 0.5988708226745347  Training 0.5235663232557588  Random State 8
# Testing 0.5764220461868523  Training 0.5276301674950307  Random State 10
# Testing 0.5863712160139809  Training 0.5289181408067878  Random State 12
# Testing 0.5732407397253843  Training 0.5344269805516503  Random State 13
# Testing 0.6164953065748817  Training 0.5196923990312539  Random State 14
# Testing 0.5731717417089228  Training 0.5306972867578187  Random State 15
# Testing 0.6419665890750208  Training 0.5111609888268616  Random State 17
# Testing 0.5671870380891657  Training 0.5351918258162571  Random State 19
# Testing 0.6026538107069697  Training 0.5282245253497018  Random State 20
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import ElasticNet
for i in range(0,401):
    
    X_train,X_test,y_train,y_test = train_test_split(features,
                                                label,
                                                test_size=0.2,
                                                random_state=i)
    model = ElasticNet()
    model.fit(X_train,y_train)
    
    train_score = model.score(X_train,y_train)
    test_score = model.score(X_test,y_test)
    
    if test_score > train_score:
        print("Testing {}  Training {}  Random State {}".format(test_score,train_score,i))
else: print("No Generalised Model Found")
# Out:
# Testing 0.6180394908118011  Training 0.5208692329278815  Random State 0
# Testing 0.6781816048492574  Training 0.5035986408608382  Random State 1
# Testing 0.5497001925031739  Training 0.5366972474597501  Random State 3
# Testing 0.55368522191461  Training 0.5357184577482179  Random State 5
# Testing 0.5995355218649996  Training 0.5235449138835173  Random State 8
# Testing 0.5763775949536027  Training 0.5279718370855173  Random State 10
# Testing 0.5862714722000478  Training 0.5289534989120173  Random State 12
# Testing 0.5742197111531726  Training 0.5344896149409628  Random State 13
# Testing 0.6162932159591425  Training 0.5196553268165631  Random State 14
# Testing 0.5737909124277373  Training 0.53061234155577  Random State 15
# Testing 0.6427996812370695  Training 0.5114285173315041  Random State 17
# Testing 0.5664539232109682  Training 0.535069324003641  Random State 19
# Testing 0.6026870835426272  Training 0.5280648830314303  Random State 20
# ...

# %% [markdown]
# # Model Building with non Linear model

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
for i in range(0,401):
    
    X_train,X_test,y_train,y_test = train_test_split(features,
                                                label,
                                                test_size=0.2,
                                                random_state=i)
    model = KNeighborsRegressor()
    model.fit(X_train,y_train)
    
    train_score = model.score(X_train,y_train)
    test_score = model.score(X_test,y_test)
    
    if test_score > train_score:
        print("Testing {}  Training {}  Random State {}".format(test_score,train_score,i))
else: print("No Generalised Model Found")
# Out:
# Testing 0.7705075521332381  Training 0.724948975481295  Random State 17
# Testing 0.7430988313010378  Training 0.7314562510439659  Random State 25
# Testing 0.7356723414662876  Training 0.7285967908520707  Random State 35
# Testing 0.799244708068867  Training 0.7199747894399003  Random State 36
# Testing 0.7412492544284467  Training 0.736589509124025  Random State 39
# Testing 0.7428941462842672  Training 0.7198837118921533  Random State 49
# Testing 0.7334512574053795  Training 0.7250978890259261  Random State 77
# Testing 0.8744633643321821  Training 0.6994866072578794  Random State 78
# Testing 0.759240607963241  Training 0.7275986681658153  Random State 80
# Testing 0.7512443574682476  Training 0.7203406384693525  Random State 87
# Testing 0.745699847636087  Training 0.7413498248808628  Random State 106
# Testing 0.7984686662633617  Training 0.7067194218808194  Random State 108
# Testing 0.7585371957761582  Training 0.7262808657262634  Random State 114
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
for i in range(0,401):
    
    X_train,X_test,y_train,y_test = train_test_split(features,
                                                label,
                                                test_size=0.2,
                                                random_state=i)
    model = DecisionTreeRegressor()
    model.fit(X_train,y_train)
    
    train_score = model.score(X_train,y_train)
    test_score = model.score(X_test,y_test)
    
    if test_score > train_score:
        print("Testing {}  Training {}  Random State {}".format(test_score,train_score,i))
else: print("No Generalised Model Found")
# Out:
# No Generalised Model Found

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
for i in range(0,401):
    
    X_train,X_test,y_train,y_test = train_test_split(features,
                                                label,
                                                test_size=0.2,
                                                random_state=i)
    model = SVR()
    model.fit(X_train,y_train)
    
    train_score = model.score(X_train,y_train)
    test_score = model.score(X_test,y_test)
    
    if test_score > train_score:
        print("Testing {}  Training {}  Random State {}".format(test_score,train_score,i))
else: print("No Generalised Model Found")
# Out:
# Testing 0.5724941879242578  Training 0.48049228590978155  Random State 0
# Testing 0.6191321571430629  Training 0.4792484062693445  Random State 1
# Testing 0.49599270437442167  Training 0.49538975758826986  Random State 3
# Testing 0.5841075309671315  Training 0.4924086370373899  Random State 5
# Testing 0.5151755135160991  Training 0.50028043113557  Random State 8
# Testing 0.5015867858712408  Training 0.49633467398702935  Random State 10
# Testing 0.5047281103640808  Training 0.49684701005011  Random State 12
# Testing 0.5508965476379719  Training 0.4914433960033837  Random State 13
# Testing 0.5741973798463083  Training 0.4804445763262202  Random State 14
# Testing 0.5730204639980071  Training 0.47524946169423765  Random State 17
# Testing 0.6093494326654985  Training 0.4818421026884213  Random State 19
# Testing 0.573644219285893  Training 0.48430071271264064  Random State 20
# Testing 0.5496450832171444  Training 0.4835571648202833  Random State 24
# ...

# %% [markdown]
# # Model Building with Essembling Methods

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostRegressor
for i in range(0,401):
    
    X_train,X_test,y_train,y_test = train_test_split(features,
                                                label,
                                                test_size=0.2,
                                                random_state=i)
    model = AdaBoostRegressor()
    model.fit(X_train,y_train)
    
    train_score = model.score(X_train,y_train)
    test_score = model.score(X_test,y_test)
    
    if test_score > train_score:
        print("Testing {}  Training {}  Random State {}".format(test_score,train_score,i))
else: print("No Generalised Model Found")
# Out:
# Testing 0.7994763473915457  Training 0.7775029883329948  Random State 78
# Testing 0.8300285689344646  Training 0.7838126396455273  Random State 347
# No Generalised Model Found

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
for i in range(0,401):
    
    X_train,X_test,y_train,y_test = train_test_split(features,
                                                label,
                                                test_size=0.2,
                                                random_state=i)
    model = GradientBoostingRegressor()
    model.fit(X_train,y_train)
    
    train_score = model.score(X_train,y_train)
    test_score = model.score(X_test,y_test)
    
    if test_score > train_score:
        print("Testing {}  Training {}  Random State {}".format(test_score,train_score,i))
else: print("No Generalised Model Found")
# Out:
# No Generalised Model Found

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
for i in range(0,401):
    
    X_train,X_test,y_train,y_test = train_test_split(features,
                                                label,
                                                test_size=0.2,
                                                random_state=i)
    model = RandomForestRegressor()
    model.fit(X_train,y_train)
    
    train_score = model.score(X_train,y_train)
    test_score = model.score(X_test,y_test)
    
    if test_score > train_score:
        print("Testing {}  Training {}  Random State {}".format(test_score,train_score,i))
else: print("No Generalised Model Found")
# Out:
# No Generalised Model Found

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import ExtraTreesRegressor
for i in range(0,401):
    
    X_train,X_test,y_train,y_test = train_test_split(features,
                                                label,
                                                test_size=0.2,
                                                random_state=i)
    model = ExtraTreesRegressor()
    model.fit(X_train,y_train)
    
    train_score = model.score(X_train,y_train)
    test_score = model.score(X_test,y_test)
    
    if test_score > train_score:
        print("Testing {}  Training {}  Random State {}".format(test_score,train_score,i))
else: print("No Generalised Model Found")
# Out:
# No Generalised Model Found

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import BaggingRegressor
for i in range(0,401):
    
    X_train,X_test,y_train,y_test = train_test_split(features,
                                                label,
                                                test_size=0.2,
                                                random_state=i)
    model = BaggingRegressor()
    model.fit(X_train,y_train)
    
    train_score = model.score(X_train,y_train)
    test_score = model.score(X_test,y_test)
    
    if test_score > train_score:
        print("Testing {}  Training {}  Random State {}".format(test_score,train_score,i))
else: print("No Generalised Model Found")
# Out:
# No Generalised Model Found

# %% [markdown]
# # Model Selection

# %% [markdown]
# 1. Linear Regression: Testing 0.7386252946513345  Training 0.5437050390563332  Random State 82
# 2. Lasso Regression: Testing 0.7217978257383137  Training 0.48652894005060354  Random State 78
# 3. Elastic net: Testing 0.7218834367839255  Training 0.48657189398002276  Random State 78
# 4.KNN : **Testing 0.8744633643321821  Training 06994866072578794  Random State 78   (Model Selected)**
# 5. DecisionTreeRegressor : **No Generalised Model Found**
# 6. SVR: Testing 0.6957432639849079  Training 0.46684468180768757  Random State 248
# 7. Ada Boost Regressor: Testing 0.8300285689344646  Training 0.7838126396455273  Random State 347
# 8. GradientBoostingRegressor: **No Generalised Model Found**
# 9. RandomForestRegressor: **No Generalised Model Found**
# 10. ExtraTreesRegressor: **No Generalised Model Found**
# 11. BaggingRegressor: **No Generalised Model Found**

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor

    
X_train,X_test,y_train,y_test = train_test_split(features,
                                                label,
                                                test_size=0.2,
                                                random_state=78)
model_final = KNeighborsRegressor()
model_final.fit(X_train,y_train)
    
train_score = model_final.score(X_train,y_train)
test_score = model_final.score(X_test,y_test)

print(test_score, train_score)
# Out:
# 0.8744633643321821 0.6994866072578794

# %% [markdown]
# # Model Evalution

# %%
	
lin_test_pred = model_final.predict(X_test)

# %%
from sklearn import metrics

# %%
	#MSE
mse= metrics.mean_squared_error(y_test,lin_test_pred)
mse
# Out:
# 23.858053012048188

# %%
#RMSE
np.sqrt(metrics.mean_squared_error(y_test,lin_test_pred))
# Out:
# 4.884470596906914

# %%
#mean absolute error
metrics.mean_absolute_error(y_test,lin_test_pred)
# Out:
# 3.7812048192771086

# %%
#R^2
metrics.r2_score(y_test,lin_test_pred)
# Out:
# 0.8744633643321821

# %%
var_test = y_test.var()
var_test
# Out:
# 190.0485295398461

# %%
#Adjusted R2
Adj_rsquare = 1-(mse/var_test)
Adj_rsquare
# Out:
# 0.8744633643321821

# %%
#Analysis of Residuals

plt.scatter(lin_test_pred,(y_test-lin_test_pred),marker='^')
plt.xlabel("Fitted")
plt.ylabel("Residual")
# Out:
# Text(0, 0.5, 'Residual')
